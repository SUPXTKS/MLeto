# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

from matplotlib import pyplot as plt

# %%
(X_train, y_train), (X_valid, y_valid) = mnist.load_data()

# %%
plt.figure(figsize=(4, 4))

for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.imshow(X_train[i], cmap='Greys')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
X_train = X_train.reshape(60000, 784).astype('float32')
X_valid = X_valid.reshape(10000, 784).astype('float32')

# %%
X_train /= 255
X_valid /= 255

# %%
y_train = keras.utils.to_categorical(y_train, 10)
y_valid = keras.utils.to_categorical(y_valid, 10)

# %%
model = Sequential()
model.add(Dense(64, input_shape=(784,), activation="sigmoid"))
model.add(Dense(10, activation="softmax"))

# %%
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                50240
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(X_train, y_train, 
    batch_size=128, epochs=200, 
    verbose=1, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/200
# 469/469 [==============================] - 6s 9ms/step - loss: 2.0781 - accuracy: 0.4932 - val_loss: 1.8324 - val_accuracy: 0.6735
# Epoch 2/200
# 469/469 [==============================] - 3s 7ms/step - loss: 1.6308 - accuracy: 0.7049 - val_loss: 1.4225 - val_accuracy: 0.7437
# Epoch 3/200
# 469/469 [==============================] - 3s 6ms/step - loss: 1.2822 - accuracy: 0.7597 - val_loss: 1.1279 - val_accuracy: 0.7949
# Epoch 4/200
# 469/469 [==============================] - 3s 7ms/step - loss: 1.0441 - accuracy: 0.8008 - val_loss: 0.9353 - val_accuracy: 0.8204
# Epoch 5/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.8872 - accuracy: 0.8253 - val_loss: 0.8071 - val_accuracy: 0.8424
# Epoch 6/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.7802 - accuracy: 0.8405 - val_loss: 0.7175 - val_accuracy: 0.8531
# Epoch 7/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.7034 - accuracy: 0.8505 - val_loss: 0.6523 - val_accuracy: 0.8638
# Epoch 8/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.6459 - accuracy: 0.8579 - val_loss: 0.6020 - val_accuracy: 0.8711
# Epoch 9/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.6012 - accuracy: 0.8642 - val_loss: 0.5627 - val_accuracy: 0.8756
# Epoch 10/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.5654 - accuracy: 0.8692 - val_loss: 0.5307 - val_accuracy: 0.8789
# Epoch 11/200
# 469/469 [==============================] - 4s 7ms/step - loss: 0.5361 - accuracy: 0.8731 - val_loss: 0.5042 - val_accuracy: 0.8831
# Epoch 12/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.5117 - accuracy: 0.8764 - val_loss: 0.4820 - val_accuracy: 0.8857
# Epoch 13/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4910 - accuracy: 0.8799 - val_loss: 0.4633 - val_accuracy: 0.8889
# Epoch 14/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4733 - accuracy: 0.8821 - val_loss: 0.4471 - val_accuracy: 0.8916
# Epoch 15/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4580 - accuracy: 0.8846 - val_loss: 0.4330 - val_accuracy: 0.8934
# Epoch 16/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4445 - accuracy: 0.8871 - val_loss: 0.4207 - val_accuracy: 0.8948
# Epoch 17/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4327 - accuracy: 0.8885 - val_loss: 0.4095 - val_accuracy: 0.8961
# Epoch 18/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4222 - accuracy: 0.8904 - val_loss: 0.4000 - val_accuracy: 0.8972
# Epoch 19/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4127 - accuracy: 0.8918 - val_loss: 0.3911 - val_accuracy: 0.8987
# Epoch 20/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4042 - accuracy: 0.8929 - val_loss: 0.3832 - val_accuracy: 0.9000
# Epoch 21/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3965 - accuracy: 0.8945 - val_loss: 0.3762 - val_accuracy: 0.9012
# Epoch 22/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3894 - accuracy: 0.8957 - val_loss: 0.3697 - val_accuracy: 0.9029
# Epoch 23/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3829 - accuracy: 0.8972 - val_loss: 0.3639 - val_accuracy: 0.9036
# Epoch 24/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3770 - accuracy: 0.8981 - val_loss: 0.3579 - val_accuracy: 0.9050
# Epoch 25/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3714 - accuracy: 0.8991 - val_loss: 0.3529 - val_accuracy: 0.9063
# Epoch 26/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3663 - accuracy: 0.9003 - val_loss: 0.3484 - val_accuracy: 0.9072
# Epoch 27/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3615 - accuracy: 0.9010 - val_loss: 0.3438 - val_accuracy: 0.9073
# Epoch 28/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3570 - accuracy: 0.9024 - val_loss: 0.3398 - val_accuracy: 0.9086
# Epoch 29/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3528 - accuracy: 0.9030 - val_loss: 0.3358 - val_accuracy: 0.9098
# Epoch 30/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3488 - accuracy: 0.9039 - val_loss: 0.3321 - val_accuracy: 0.9099
# Epoch 31/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3451 - accuracy: 0.9044 - val_loss: 0.3285 - val_accuracy: 0.9111
# Epoch 32/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3415 - accuracy: 0.9053 - val_loss: 0.3254 - val_accuracy: 0.9119
# Epoch 33/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3381 - accuracy: 0.9057 - val_loss: 0.3223 - val_accuracy: 0.9122
# Epoch 34/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3349 - accuracy: 0.9066 - val_loss: 0.3192 - val_accuracy: 0.9128
# Epoch 35/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3319 - accuracy: 0.9071 - val_loss: 0.3167 - val_accuracy: 0.9132
# Epoch 36/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3289 - accuracy: 0.9079 - val_loss: 0.3138 - val_accuracy: 0.9133
# Epoch 37/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3261 - accuracy: 0.9084 - val_loss: 0.3113 - val_accuracy: 0.9149
# Epoch 38/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3234 - accuracy: 0.9090 - val_loss: 0.3090 - val_accuracy: 0.9146
# Epoch 39/200
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3209 - accuracy: 0.9097 - val_loss: 0.3065 - val_accuracy: 0.9154
# Epoch 40/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3184 - accuracy: 0.9103 - val_loss: 0.3043 - val_accuracy: 0.9159
# Epoch 41/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3159 - accuracy: 0.9109 - val_loss: 0.3020 - val_accuracy: 0.9168
# Epoch 42/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3137 - accuracy: 0.9116 - val_loss: 0.2998 - val_accuracy: 0.9171
# Epoch 43/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3114 - accuracy: 0.9121 - val_loss: 0.2979 - val_accuracy: 0.9176
# Epoch 44/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3092 - accuracy: 0.9127 - val_loss: 0.2961 - val_accuracy: 0.9182
# Epoch 45/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3072 - accuracy: 0.9130 - val_loss: 0.2941 - val_accuracy: 0.9189
# Epoch 46/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3051 - accuracy: 0.9137 - val_loss: 0.2922 - val_accuracy: 0.9195
# Epoch 47/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3031 - accuracy: 0.9141 - val_loss: 0.2903 - val_accuracy: 0.9195
# Epoch 48/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3012 - accuracy: 0.9149 - val_loss: 0.2885 - val_accuracy: 0.9202
# Epoch 49/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2993 - accuracy: 0.9152 - val_loss: 0.2868 - val_accuracy: 0.9207
# Epoch 50/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2975 - accuracy: 0.9158 - val_loss: 0.2852 - val_accuracy: 0.9205
# Epoch 51/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2957 - accuracy: 0.9162 - val_loss: 0.2837 - val_accuracy: 0.9208
# Epoch 52/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2939 - accuracy: 0.9168 - val_loss: 0.2821 - val_accuracy: 0.9218
# Epoch 53/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2922 - accuracy: 0.9169 - val_loss: 0.2806 - val_accuracy: 0.9222
# Epoch 54/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2906 - accuracy: 0.9175 - val_loss: 0.2794 - val_accuracy: 0.9223
# Epoch 55/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2890 - accuracy: 0.9180 - val_loss: 0.2776 - val_accuracy: 0.9223
# Epoch 56/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2874 - accuracy: 0.9188 - val_loss: 0.2761 - val_accuracy: 0.9231
# Epoch 57/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2858 - accuracy: 0.9193 - val_loss: 0.2746 - val_accuracy: 0.9230
# Epoch 58/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2843 - accuracy: 0.9194 - val_loss: 0.2735 - val_accuracy: 0.9237
# Epoch 59/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2828 - accuracy: 0.9197 - val_loss: 0.2719 - val_accuracy: 0.9236
# Epoch 60/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2813 - accuracy: 0.9204 - val_loss: 0.2708 - val_accuracy: 0.9241
# Epoch 61/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2798 - accuracy: 0.9207 - val_loss: 0.2693 - val_accuracy: 0.9248
# Epoch 62/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2784 - accuracy: 0.9210 - val_loss: 0.2681 - val_accuracy: 0.9246
# Epoch 63/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2770 - accuracy: 0.9215 - val_loss: 0.2669 - val_accuracy: 0.9254
# Epoch 64/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2756 - accuracy: 0.9219 - val_loss: 0.2655 - val_accuracy: 0.9251
# Epoch 65/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2743 - accuracy: 0.9222 - val_loss: 0.2643 - val_accuracy: 0.9260
# Epoch 66/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2729 - accuracy: 0.9223 - val_loss: 0.2631 - val_accuracy: 0.9263
# Epoch 67/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2716 - accuracy: 0.9227 - val_loss: 0.2620 - val_accuracy: 0.9268
# Epoch 68/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2703 - accuracy: 0.9232 - val_loss: 0.2609 - val_accuracy: 0.9267
# Epoch 69/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2691 - accuracy: 0.9235 - val_loss: 0.2597 - val_accuracy: 0.9270
# Epoch 70/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2678 - accuracy: 0.9239 - val_loss: 0.2586 - val_accuracy: 0.9273
# Epoch 71/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2665 - accuracy: 0.9244 - val_loss: 0.2574 - val_accuracy: 0.9272
# Epoch 72/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2653 - accuracy: 0.9245 - val_loss: 0.2564 - val_accuracy: 0.9276
# Epoch 73/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2641 - accuracy: 0.9249 - val_loss: 0.2552 - val_accuracy: 0.9275
# Epoch 74/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2629 - accuracy: 0.9254 - val_loss: 0.2542 - val_accuracy: 0.9284
# Epoch 75/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2617 - accuracy: 0.9257 - val_loss: 0.2532 - val_accuracy: 0.9279
# Epoch 76/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2606 - accuracy: 0.9262 - val_loss: 0.2520 - val_accuracy: 0.9286
# Epoch 77/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2594 - accuracy: 0.9262 - val_loss: 0.2510 - val_accuracy: 0.9288
# Epoch 78/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2583 - accuracy: 0.9266 - val_loss: 0.2500 - val_accuracy: 0.9290
# Epoch 79/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2571 - accuracy: 0.9270 - val_loss: 0.2489 - val_accuracy: 0.9300
# Epoch 80/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2560 - accuracy: 0.9273 - val_loss: 0.2478 - val_accuracy: 0.9298
# Epoch 81/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2549 - accuracy: 0.9276 - val_loss: 0.2470 - val_accuracy: 0.9300
# Epoch 82/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2538 - accuracy: 0.9279 - val_loss: 0.2460 - val_accuracy: 0.9300
# Epoch 83/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2528 - accuracy: 0.9282 - val_loss: 0.2451 - val_accuracy: 0.9306
# Epoch 84/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2517 - accuracy: 0.9287 - val_loss: 0.2441 - val_accuracy: 0.9308
# Epoch 85/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2507 - accuracy: 0.9288 - val_loss: 0.2430 - val_accuracy: 0.9309
# Epoch 86/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2496 - accuracy: 0.9291 - val_loss: 0.2421 - val_accuracy: 0.9316
# Epoch 87/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2486 - accuracy: 0.9297 - val_loss: 0.2413 - val_accuracy: 0.9312
# Epoch 88/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2476 - accuracy: 0.9298 - val_loss: 0.2403 - val_accuracy: 0.9314
# Epoch 89/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2466 - accuracy: 0.9305 - val_loss: 0.2393 - val_accuracy: 0.9316
# Epoch 90/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2456 - accuracy: 0.9304 - val_loss: 0.2384 - val_accuracy: 0.9320
# Epoch 91/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2446 - accuracy: 0.9306 - val_loss: 0.2376 - val_accuracy: 0.9318
# Epoch 92/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2436 - accuracy: 0.9308 - val_loss: 0.2367 - val_accuracy: 0.9322
# Epoch 93/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2426 - accuracy: 0.9313 - val_loss: 0.2358 - val_accuracy: 0.9321
# Epoch 94/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2417 - accuracy: 0.9318 - val_loss: 0.2350 - val_accuracy: 0.9324
# Epoch 95/200
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2407 - accuracy: 0.9317 - val_loss: 0.2342 - val_accuracy: 0.9327
# Epoch 96/200
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2398 - accuracy: 0.9320 - val_loss: 0.2334 - val_accuracy: 0.9327
# Epoch 97/200
# 187/469 [==========>...................] - ETA: 1s - loss: 0.2358 - accuracy: 0.9336
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Student\SUPXTKS\test.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Student/SUPXTKS/test.ipynb#ch0000008?line=0'>1</a> model.fit(X_train, y_train,
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/SUPXTKS/test.ipynb#ch0000008?line=1'>2</a>     batch_size=128, epochs=200,
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/SUPXTKS/test.ipynb#ch0000008?line=2'>3</a>     verbose=1, validation_data=(X_valid, y_valid))
#
# File c:\Users\Student\venv\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Student\venv\lib\site-packages\keras\engine\training.py:1401, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/training.py?line=1398'>1399</a> with data_handler.catch_stop_iteration():
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/training.py?line=1399'>1400</a>   data_handler._initial_step = self._maybe_load_initial_step_from_ckpt()  # pylint: disable=protected-access
# -> <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/training.py?line=1400'>1401</a>   for step in data_handler.steps():
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/training.py?line=1401'>1402</a>     with tf.profiler.experimental.Trace(
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/training.py?line=1402'>1403</a>         'train',
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/training.py?line=1403'>1404</a>         epoch_num=epoch,
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/training.py?line=1404'>1405</a>         step_num=step,
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/training.py?line=1405'>1406</a>         batch_size=batch_size,
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/training.py?line=1406'>1407</a>         _r=1):
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/training.py?line=1407'>1408</a>       callbacks.on_train_batch_begin(step)
#
# File c:\Users\Student\venv\lib\site-packages\keras\engine\data_adapter.py:1248, in DataHandler.steps(self)
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/data_adapter.py?line=1245'>1246</a> if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/data_adapter.py?line=1246'>1247</a>   break
# -> <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/data_adapter.py?line=1247'>1248</a> original_spe = self._steps_per_execution.numpy().item()
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/data_adapter.py?line=1248'>1249</a> can_run_full_execution = (
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/data_adapter.py?line=1249'>1250</a>     original_spe == 1 or
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/data_adapter.py?line=1250'>1251</a>     self._inferred_steps is None or
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/data_adapter.py?line=1251'>1252</a>     self._inferred_steps - self._current_step >=
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/data_adapter.py?line=1252'>1253</a>     original_spe)
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/keras/engine/data_adapter.py?line=1254'>1255</a> if can_run_full_execution:
#
# File c:\Users\Student\venv\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:637, in BaseResourceVariable.numpy(self)
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/resource_variable_ops.py?line=634'>635</a> def numpy(self):
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/resource_variable_ops.py?line=635'>636</a>   if context.executing_eagerly():
# --> <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/resource_variable_ops.py?line=636'>637</a>     return self.read_value().numpy()
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/resource_variable_ops.py?line=637'>638</a>   raise NotImplementedError(
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/resource_variable_ops.py?line=638'>639</a>       "numpy() is only available when eager execution is enabled.")
#
# File c:\Users\Student\venv\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:715, in BaseResourceVariable.read_value(self)
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/resource_variable_ops.py?line=711'>712</a>   value = self._read_variable_op()
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/resource_variable_ops.py?line=712'>713</a> # Return an identity so it can get placed on whatever device the context
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/resource_variable_ops.py?line=713'>714</a> # specifies instead of the device where the variable is.
# --> <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/resource_variable_ops.py?line=714'>715</a> return array_ops.identity(value)
#
# File c:\Users\Student\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=147'>148</a> filtered_tb = None
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=148'>149</a> try:
# --> <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=149'>150</a>   return fn(*args, **kwargs)
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=150'>151</a> except Exception as e:
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=151'>152</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Student\venv\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/util/dispatch.py?line=1079'>1080</a> # Fallback dispatch system (dispatch v1):
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/util/dispatch.py?line=1080'>1081</a> try:
# -> <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/util/dispatch.py?line=1081'>1082</a>   return dispatch_target(*args, **kwargs)
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/util/dispatch.py?line=1082'>1083</a> except (TypeError, ValueError):
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/util/dispatch.py?line=1083'>1084</a>   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/util/dispatch.py?line=1084'>1085</a>   # TypeError, when given unexpected types.  So we need to catch both.
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/util/dispatch.py?line=1085'>1086</a>   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\Student\venv\lib\site-packages\tensorflow\python\ops\array_ops.py:295, in identity(input, name)
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/array_ops.py?line=290'>291</a> if context.executing_eagerly() and not hasattr(input, "graph"):
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/array_ops.py?line=291'>292</a>   # Make sure we get an input with handle data attached from resource
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/array_ops.py?line=292'>293</a>   # variables. Variables have correct handle data when graph building.
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/array_ops.py?line=293'>294</a>   input = ops.convert_to_tensor(input)
# --> <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/array_ops.py?line=294'>295</a> ret = gen_array_ops.identity(input, name=name)
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/array_ops.py?line=295'>296</a> # Propagate handle data for happier shape inference for resource variables.
#     <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/array_ops.py?line=296'>297</a> if hasattr(input, "_handle_data"):
#
# File c:\Users\Student\venv\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:4063, in identity(input, name)
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=4060'>4061</a> if tld.is_eager:
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=4061'>4062</a>   try:
# -> <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=4062'>4063</a>     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=4063'>4064</a>       _ctx, "Identity", name, input)
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=4064'>4065</a>     return _result
#    <a href='file:///c%3A/Users/Student/venv/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=4065'>4066</a>   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
